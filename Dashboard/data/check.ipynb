# %%
import pandas as pd

# %%
df = pd.read_csv('article.csv')
df
# Out:
#                                                   title  \
# 0               Hơn 300 cổ phiếu trên sàn HoSE giảm giá
# 1                      Chứng khoán giảm mạnh cuối phiên
# 2                               VN-Index biến động mạnh
# 3                    Cổ phiếu HAG ngược dòng thị trường
# 4                  Cổ phiếu ngân hàng tiếp tục giảm sâu
# ...                                                 ...
# 2301  BTS: Công bố thông tin ký kết hợp đồng với ngư...
# 2302  VNM: Thông báo giao dịch cổ phiếu của tổ chức ...
# 2303  Kết quả kinh doanh quý 3 tích cực, VHC tạm ứng...
# 2304  PMC: Nghị quyết Đại hội đồng cổ đông bất thườn...
# 2305  KDH: Quyết định về việc thay đổi đăng ký niêm yết
#
#                                                    link  \
# 0     https://vnexpress.net/chung-khoan-hom-nay-15-1...
# 1     https://vnexpress.net/chung-khoan-giam-manh-cu...
# 2     https://vnexpress.net/vn-index-bien-dong-manh-...
# 3     https://vnexpress.net/chung-khoan-hom-nay-12-1...
# ...

# %%
# Thời gian của bộ data này 
max_date = df['date'].max()
print(max_date)
# Out:
# 2024-12-01
